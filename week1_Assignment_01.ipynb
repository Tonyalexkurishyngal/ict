# %% [markdown]
# ### **1. Read the dataset to python environment**

# %%
# Mount drive #if needed
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlrd in /usr/local/lib/python3.9/dist-packages (2.0.1)

# %%
file_path = '/content/drive/MyDrive/ICT_study/iris.xls'

# %%
import pandas as pd

iris = pd.read_excel(file_path)

print(iris)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### **2. Display the columns in the dataset.**

# %%
print(iris.columns)
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ### **3. Calculate the mean of each column of the dataset.**

# %%
print(iris.mean())
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64
# <ipython-input-8-ae4f521d41bd>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(iris.mean())

# %% [markdown]
# ### **4. Check for the null values present in the dataset.**

# %%
print(iris.isnull().sum())
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ### **5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.**

# %% [markdown]
# # **Visualizations 1**

# %%
import matplotlib.pyplot as plt

plt.scatter(iris['SL'], iris['SW'])
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Sepal Length vs Sepal Width')
plt.show()

# %% [markdown]
# # **Visualizations 2**

# %%
import seaborn as sns

sns.boxplot(x='Classification', y='PL', data=iris)
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.title('Petal Length by Species')
plt.show()

# %% [markdown]
# # **Visualizations 3**

# %%
plt.hist(iris['SW'], bins=10)
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Width')
plt.show()
